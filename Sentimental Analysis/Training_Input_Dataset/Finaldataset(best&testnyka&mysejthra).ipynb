# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
bestfoodapps1 = pd.read_csv('/content/drive/MyDrive/Final Dataset/10bestfoodfinal/bestfoodapps1.csv')
bestfoodapps1.head()
# Out:
#    Unnamed: 0                                  Translated_Review Sentiment
# 0           7              It helpful site ! It help foods get !  Positive
# 1           8                                          good you.  Positive
# 2          14  Mrs sunita bhati I thankful developers,to make...  Positive
# 3          17                                          good nice  Positive
# 4          25                              Very good Simply good  Positive

# %%
bestfoodapps3 = pd.read_csv('/content/drive/MyDrive/Final Dataset/10bestfoodfinal/bestfoodapps3.csv')
bestfoodapps3.head()
# Out:
#    Unnamed: 0                           Translated_Review Sentiment
# 0           1  help eating healthy exercise regular basis  Positive
# 1           2  works great especially going grocery store  Positive
# 2           3                                best idea us  Positive
# 3           4                                    best way  Positive
# 4           5                                     amazing  Positive

# %%
bestfoodapps31 = pd.read_csv('/content/drive/MyDrive/Final Dataset/10bestfoodfinal/bestfoodapps31.csv')
bestfoodapps31.head()
# Out:
#    Unnamed: 0                                  Translated_Review Sentiment
# 0           0  like eat delicious food cooking food case best...  Positive
# 1           6                                looking forward app   Neutral
# 2          12             good health good health first priority  Positive
# 3          27                                               good  Positive
# 4          28  thanks advice downloaded adobe reader still ge...  Positive

# %%
bestfoodappsfinaldataset = pd.concat([bestfoodapps1, bestfoodapps3,bestfoodapps31], axis=0)
bestfoodappsfinaldataset.head()
# Out:
#    Unnamed: 0                                  Translated_Review Sentiment
# 0           7              It helpful site ! It help foods get !  Positive
# 1           8                                          good you.  Positive
# 2          14  Mrs sunita bhati I thankful developers,to make...  Positive
# 3          17                                          good nice  Positive
# 4          25                              Very good Simply good  Positive

# %%
bestfoodappsfinaldataset =bestfoodappsfinaldataset.dropna()

# %%
bestfoodappsfinaldataset.isnull().sum()
# Out:
# Unnamed: 0           0
# Translated_Review    0
# Sentiment            0
# dtype: int64

# %%
bestfoodappsfinaldataset.shape
# Out:
# (3371, 3)

# %%
bestfoodappsfinaldataset = bestfoodappsfinaldataset.drop(columns='Unnamed: 0', axis=0)
bestfoodappsfinaldataset.head()
# Out:
#                                    Translated_Review Sentiment
# 0              It helpful site ! It help foods get !  Positive
# 1                                          good you.  Positive
# 2  Mrs sunita bhati I thankful developers,to make...  Positive
# 3                                          good nice  Positive
# 4                              Very good Simply good  Positive

# %%
bestfoodappsfinaldataset['Sentiment'].value_counts()
# Out:
# Positive    2180
# Negative     673
# Neutral      518
# Name: Sentiment, dtype: int64

# %%
label={'Positive' : +2, 'Negative' : -1 , 'Neutral' : +1}
bestfoodappsfinaldataset['label']= bestfoodappsfinaldataset['Sentiment'].map(label)
bestfoodappsfinaldataset.sample(20)
# Out:
#                                       Translated_Review Sentiment  label
# 106   like pace variety hear timer music playing mut...  Positive      2
# 1211  slow load new messages showing messages days a...  Negative     -1
# 1102               lags much device sometimes game work  Negative     -1
# 42    short simple sweet super easy took less mins o...  Positive      2
# 903           prompted rate time already rated annoying  Negative     -1
# 1949  u pls fix lag keeps glitching across map go bl...  Negative     -1
# 1056  game help little brother caleb littie sister m...  Negative     -1
# 14                                          Good V good  Positive      2
# 1122  ads much flashing jumping around cannot even r...  Positive      2
# 2230  excellent app thank time effort please add pdf...  Positive      2
# 316   Adobe Acrobat reader good lets open , edit ( k...  Positive      2
# 972   please add sound setting children try play lou...  Positive      2
# ...

# %%
bestfoodappsfinaldataset = bestfoodappsfinaldataset.drop(columns='Sentiment', axis=0)
bestfoodappsfinaldataset.head()
# Out:
#                                    Translated_Review  label
# 0              It helpful site ! It help foods get !      2
# 1                                          good you.      2
# 2  Mrs sunita bhati I thankful developers,to make...      2
# 3                                          good nice      2
# 4                              Very good Simply good      2

# %%
Finalmerge11cleaned = pd.read_csv('/content/drive/MyDrive/Final Dataset/mysejthraFinal/Finalmerge11cleaned.csv')
Finalmerge11cleaned.sample(10)
# Out:
#                                              Review  Rating
# 10898                 gets quicker smoother updates       5
# 4205   proud malaysia good apps malaysia government       5
# 8374                               easy convenience       5
# 13515                                       awesome       5
# 12070                                      greatest       5
# 15019                   issue using apps today keep       1
# 12362                                    great apps       5
# 11951                                           new       5
# 3883                                           good       5
# 11885                                         great       5

# %%
Finalmerge11cleaned['Rating'].value_counts()
# Out:
# 5    10343
# 3     4157
# 1     1332
# Name: Rating, dtype: int64

# %%
Finalmergenegcleaned = pd.read_csv('/content/drive/MyDrive/Final Dataset/mysejthraFinal/Finalmergenegcleaned.csv')
Finalmergenegcleaned.head()
# Out:
#                                               Review  Rating
# 0  answering covid status assessment january time...       1
# 1  wrote help desk missing vaccinations info digi...       1
# 2  cant change reset password need change want go...       1
# 3  many bugs completed doses vaccination astrazen...       1
# 4  already uninstall reinstall still change submi...       1

# %%
Finalmergenegcleaned['Rating'].value_counts()
# Out:
# 1    5415
# Name: Rating, dtype: int64

# %%
mysejthrafinaldataset = pd.concat([Finalmerge11cleaned, Finalmergenegcleaned], axis=0)
mysejthrafinaldataset.head()
# Out:
#                                               Review  Rating
# 0  nice contact tracing via bluetooth wi fi scann...       5
# 1  nice app nice makes auto check improvements al...       5
# 2  great app especially update would nice date co...       5
# 3  would great convenience ensure users checked u...       5
# 4  updated helpdesk working ios please kindly loo...       5

# %%
mysejthrafinaldataset['Rating'].value_counts()
# Out:
# 5    10343
# 1     6747
# 3     4157
# Name: Rating, dtype: int64

# %%
label={ 5 : +2, 1 : -1 , 3 : 1}
mysejthrafinaldataset['label']= mysejthrafinaldataset['Rating'].map(label)
mysejthrafinaldataset.head()
# Out:
#                                               Review  Rating  label
# 0  nice contact tracing via bluetooth wi fi scann...       5      2
# 1  nice app nice makes auto check improvements al...       5      2
# 2  great app especially update would nice date co...       5      2
# 3  would great convenience ensure users checked u...       5      2
# 4  updated helpdesk working ios please kindly loo...       5      2

# %%
mysejthrafinaldataset = mysejthrafinaldataset.rename(columns={"Review": "Translated_Review"})
mysejthrafinaldataset.head()
# Out:
#                                    Translated_Review  Rating  label
# 0  nice contact tracing via bluetooth wi fi scann...       5      2
# 1  nice app nice makes auto check improvements al...       5      2
# 2  great app especially update would nice date co...       5      2
# 3  would great convenience ensure users checked u...       5      2
# 4  updated helpdesk working ios please kindly loo...       5      2

# %%
mysejthrafinaldataset = mysejthrafinaldataset.drop(columns='Rating', axis=0)
mysejthrafinaldataset.head()
# Out:
#                                    Translated_Review  label
# 0  nice contact tracing via bluetooth wi fi scann...      2
# 1  nice app nice makes auto check improvements al...      2
# 2  great app especially update would nice date co...      2
# 3  would great convenience ensure users checked u...      2
# 4  updated helpdesk working ios please kindly loo...      2

# %%
nyka_neutral11 = pd.read_csv('/content/drive/MyDrive/Final Dataset/tesknykafinal/nyka_neutral11.csv')
nyka_neutral11.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                  content sentiment_labels
# 0           0             9                     good         POSITIVE
# 1           1            29                     good         POSITIVE
# 2           2            31                 nice app         POSITIVE
# 3           5            48                     good         POSITIVE
# 4           7            54  great experience naykaa         POSITIVE

# %%
nyka_neutral2 = pd.read_csv('/content/drive/MyDrive/Final Dataset/tesknykafinal/nyka_neutral2.csv')
nyka_neutral2.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  \
# 0           3            35
# 1           4            42
# 2           6            53
# 3           8            58
# 4           9            59
#
#                                              content sentiment_labels
# 0                              courier serv horrible          NEUTRAL
# 1                                               best         POSITIVE
# 2                reliable app send original products          NEUTRAL
# 3  prices high comparison amazon nykaa many produ...          NEUTRAL
# 4  delivery charges way high location often coupo...          NEUTRAL

# %%
nyka_neutral21 = pd.read_csv('/content/drive/MyDrive/Final Dataset/tesknykafinal/nyka_neutral21.csv')
nyka_neutral21.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  \
# 0          25           160
# 1          83           443
# 2         124           637
# 3         175           938
# 4         184           986
#
#                                              content sentiment_labels
# 0                                                bad         NEGATIVE
# 1  product awesome n sales best delivery service ...         NEGATIVE
# 2  reliable gave stars less oriflame avon product...         NEGATIVE
# 3               thankyou solving issues recent order          NEUTRAL
# 4  issue delivery message comes way order deliver...         NEGATIVE

# %%
testnyka_NEG_Cleaned = pd.read_csv('/content/drive/MyDrive/Final Dataset/tesknykafinal/testnyka_NEG_Cleaned.csv')
testnyka_NEG_Cleaned.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  \
# 0           0            27
# 1           1            30
# 2           2           112
# 3           3           116
# 4           4           125
#
#                                              content sentiment_labels
# 0  Very bad service...my order was not delivered ...         NEGATIVE
# 1                      Worst apss ..i have ever seen         NEGATIVE
# 2  i bought a maybelline new york fit me matte+po...         NEGATIVE
# 3  I have been associated with Nykaa from last 1 ...         NEGATIVE
# 4  When i open the app ...it just takes toooo lon...         NEGATIVE

# %%
testnyka_POS_cleaned = pd.read_csv('/content/drive/MyDrive/Final Dataset/tesknykafinal/testnyka_POS_cleaned.csv')
testnyka_POS_cleaned.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  \
# 0           1         27254
# 1           2         25086
# 2           3          1590
# 3           4         38494
# 4           5         12832
#
#                                              content sentiment_labels
# 0                         user friendly, easy to use         POSITIVE
# 1  Love shopping at Nykaa and their app is so ama...         POSITIVE
# 2                  Best product delivery experience.         POSITIVE
# 3                                        I love this         POSITIVE
# 4                                 i jst love dis app         POSITIVE

# %%
testnykafinaldataset = pd.concat([nyka_neutral11, nyka_neutral2,nyka_neutral21,testnyka_NEG_Cleaned,testnyka_POS_cleaned], axis=0)
testnykafinaldataset.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                  content sentiment_labels
# 0           0             9                     good         POSITIVE
# 1           1            29                     good         POSITIVE
# 2           2            31                 nice app         POSITIVE
# 3           5            48                     good         POSITIVE
# 4           7            54  great experience naykaa         POSITIVE

# %%
testnykafinaldataset.shape
# Out:
# (7575, 4)

# %%
testnykafinaldataset = testnykafinaldataset.drop(columns=['Unnamed: 0','Unnamed: 0.1'], axis=0)
testnykafinaldataset.head()
# Out:
#                    content sentiment_labels
# 0                     good         POSITIVE
# 1                     good         POSITIVE
# 2                 nice app         POSITIVE
# 3                     good         POSITIVE
# 4  great experience naykaa         POSITIVE

# %%
testnykafinaldataset.sample(10)
# Out:
#                                                 content sentiment_labels
# 428   They should not have a return policy when they...         NEGATIVE
# 2102                                            Awesome         POSITIVE
# 343                                     awesome service         POSITIVE
# 2471  very bad ....products are fake n duplicate ......         NEGATIVE
# 2556                                            Thank u         POSITIVE
# 160   nice app get every thing quick nice products n...         POSITIVE
# 1516                                           Crashing         NEGATIVE
# 1023  Poor customer service..... Playing with people...         NEGATIVE
# 418                                             Awesome         POSITIVE
# 1008  It's very horrible. They thinks they are right...         NEGATIVE

# %%
label={'POSITIVE' : +2, 'NEGATIVE' : -1 , 'NEUTRAL' : +1}
testnykafinaldataset['label']= testnykafinaldataset['sentiment_labels'].map(label)
testnykafinaldataset.sample(10)
# Out:
#                                                 content sentiment_labels  \
# 124                                             love it         POSITIVE
# 1     Love shopping at Nykaa and their app is so ama...         POSITIVE
# 1163                                  best makeup lover         POSITIVE
# 698                          beautiful app thanku nykaa         POSITIVE
# 640                           Please make cod available         NEGATIVE
# 1178                                               good         POSITIVE
# 142   Very poor customer support...even after compla...         NEGATIVE
# 308                                            good app         POSITIVE
# 1584                  very organized and user friendly.         POSITIVE
# 459   they dont have proper return policy. they open...         NEGATIVE
#
#       label
# 124     2.0
# 1       2.0
# 1163    2.0
# 698     2.0
# 640    -1.0
# 1178    2.0
# 142    -1.0
# 308     2.0
# 1584    2.0
# 459    -1.0

# %%
testnykafinaldataset = testnykafinaldataset.rename(columns={"content": "Translated_Review"})
testnykafinaldataset.head()
# Out:
#          Translated_Review sentiment_labels  label
# 0                     good         POSITIVE    2.0
# 1                     good         POSITIVE    2.0
# 2                 nice app         POSITIVE    2.0
# 3                     good         POSITIVE    2.0
# 4  great experience naykaa         POSITIVE    2.0

# %%
testnykafinaldataset = testnykafinaldataset.drop(columns='sentiment_labels', axis=0)
testnykafinaldataset.head()
# Out:
#          Translated_Review  label
# 0                     good    2.0
# 1                     good    2.0
# 2                 nice app    2.0
# 3                     good    2.0
# 4  great experience naykaa    2.0

# %%
FinalDatasetmerged = pd.concat([bestfoodappsfinaldataset, mysejthrafinaldataset,testnykafinaldataset], axis=0)
FinalDatasetmerged.head()
# Out:
#                                    Translated_Review  label
# 0              It helpful site ! It help foods get !    2.0
# 1                                          good you.    2.0
# 2  Mrs sunita bhati I thankful developers,to make...    2.0
# 3                                          good nice    2.0
# 4                              Very good Simply good    2.0

# %%
FinalDatasetmerged.shape
# Out:
# (32193, 2)

# %%
FinalDatasetmerged['label'].value_counts()
# Out:
#  2.0    17135
# -1.0    10007
#  1.0     5047
# Name: label, dtype: int64

# %%
from sklearn.utils import shuffle
FinalDatasetmerged = shuffle(FinalDatasetmerged)

# %%
FinalDatasetmerged.head(10)
# Out:
#                                       Translated_Review  label
# 2881  feature search hotspot location able function ...   -1.0
# 6                                                  good    2.0
# 8045                                          easy scan    2.0
# 4015                  good lindungi diri lindungi semua    2.0
# 333   Extremely happy with the experience. They deli...    2.0
# 9713        fast efficient data processing excuse using    2.0
# 26                                       nice super get    2.0
# 5132                                                bad   -1.0
# 152   mom small kids writing workout schedule meal p...    2.0
# 413                                     genuine product    2.0

# %%
FinalDatasetmerged.to_csv('FinalDatasetmerged.csv',index=False)
