# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# foodbestapp = pd.read_csv('/content/drive/MyDrive/Final project/bestfoodapps.csv')
# foodbestapp
# Out:
#                                       Translated_Review Sentiment
# 0     I like eat delicious food. That's I'm cooking ...  Positive
# 1       This help eating healthy exercise regular basis  Positive
# 2            Works great especially going grocery store  Positive
# 3                                          Best idea us  Positive
# 4                                              Best way  Positive
# ...                                                 ...       ...
# 3470                                          shoulders   Neutral
# 3471                                                Wow  Positive
# 3472                                                huh   Neutral
# 3473                                 This best students  Positive
# 3474                                      Best learning  Positive
#
# [3475 rows x 2 columns]

# %%
# foodbestapp.shape
# Out:
# (3475, 2)

# %%
# foodbestapp=foodbestapp.dropna()
# foodbestapp.shape
# Out:
# (3403, 2)

# %%
# foodbestapp.isnull().sum()
# Out:
# Translated_Review    0
# Sentiment            0
# dtype: int64

# %%
# #Select Only english language reviews
# foodbestapp = foodbestapp[foodbestapp.Translated_Review.map(lambda x: x.isascii())]
# foodbestapp.shape
# Out:
# (3376, 2)

# %%
# foodbestapp["Sentiment"].value_counts()
# Out:
# Positive    2138
# Negative     674
# Neutral      564
# Name: Sentiment, dtype: int64

# %%
# foodbestapp.to_csv("foodbestappfinal.csv")

# %%
testnyka = pd.read_csv('/content/drive/MyDrive/Final project/test_nykaa_review_sentiment.csv')
testnyka
# Out:
#                                                  content sentiment_labels
# 0                                                Great 😄          NEUTRAL
# 1                                                   👌👌👌👌         POSITIVE
# 2                                                   Good         POSITIVE
# 3                      All items and brands at one place         POSITIVE
# 4      A app in which u can find most of the makeup p...         POSITIVE
# ...                                                  ...              ...
# 38881                                            Amazing         POSITIVE
# 38882            Its a very good app for online shopping          NEUTRAL
# 38883                                      very reliable          NEUTRAL
# 38884  I have bought nova products dat are amazing in...         NEGATIVE
# 38885                          luv u nykaa u are awesome         POSITIVE
#
# [38886 rows x 2 columns]

# %%
testnyka=testnyka.dropna()
testnyka.shape
# Out:
# (38886, 2)

# %%
# Select Only english language reviews
testnyka = testnyka[testnyka.content.map(lambda x: x.isascii())]
testnyka.shape
# Out:
# (32709, 2)

# %%
testnyka["sentiment_labels"].value_counts()
# Out:
# POSITIVE    22718
# NEUTRAL      6925
# NEGATIVE     3066
# Name: sentiment_labels, dtype: int64

# %%
# #Select raws that contain sentiment_labels Neutral
# testnyka_Neutral = testnyka.loc[testnyka['sentiment_labels'].isin(['NEUTRAL'])]
# testnyka_Neutral.head()
# Out:
#                      content sentiment_labels
# 9                       Good          NEUTRAL
# 29                      Good          NEUTRAL
# 31                  Nice app          NEUTRAL
# 35  Courier serv is horrible          NEUTRAL
# 42                      Best          NEUTRAL

# %%
# testnyka_Neutral.shape
# Out:
# (6925, 2)

# %%
# testnyka.to_csv("testnykacleaned1.csv")

# %%
# testnyka_Neutral.to_csv("testnyka_Neutral.csv")

# %%
testnyka_Neutral_cleaned = pd.read_csv('/content/drive/MyDrive/Final project/testnyka_Neutral_cleaned.csv')
testnyka_Neutral_cleaned.head()
# Out:
#    Unnamed: 0                   content sentiment_labels
# 0           9                      Good          NEUTRAL
# 1          29                      Good          NEUTRAL
# 2          31                  Nice app          NEUTRAL
# 3          35  Courier serv is horrible          NEUTRAL
# 4          42                      Best         POSITIVE

# %%
testnyka_Neutral_cleaned_final = testnyka_Neutral_cleaned[:2022]
testnyka_Neutral_cleaned_final
# Out:
#       Unnamed: 0                                            content  \
# 0              9                                               Good
# 1             29                                               Good
# 2             31                                           Nice app
# 3             35                           Courier serv is horrible
# 4             42                                               Best
# ...          ...                                                ...
# 2017       11037                                          I love it
# 2018       11042                            it's great shopping app
# 2019       11046  My order got cancelled without informing me, w...
# 2020       11047  It is a good app but the shipping charge is to...
# 2021       11049  They should provide cash on delivery service f...
#
#      sentiment_labels
# 0             NEUTRAL
# 1             NEUTRAL
# 2             NEUTRAL
# 3             NEUTRAL
# 4            POSITIVE
# ...

# %%
testnyka_Neutral_cleaned_final["sentiment_labels"].value_counts()
# Out:
# NEUTRAL     1738
# POSITIVE     276
# Name: sentiment_labels, dtype: int64

# %%
testnyka_Neutral_cleaned_final.to_csv("testnyka_Neutral_cleaned_final.csv")

# %%
#Select raws that contain sentiment_labels POSITIVE 
testnyka_NEGATIVE = testnyka.loc[testnyka['sentiment_labels'].isin(['NEGATIVE'])]
testnyka_NEGATIVE.head()
# Out:
#                                                content sentiment_labels
# 27   Very bad service...my order was not delivered ...         NEGATIVE
# 30                       Worst apss ..i have ever seen         NEGATIVE
# 93                                                Good         NEGATIVE
# 109    Product is good bt customer service is too bad.         NEGATIVE
# 111  I have ordered but its one week no info n no m...         NEGATIVE

# %%
testnyka_NEGATIVE.shape
# Out:
# (2605, 2)

# %%
testnyka_NEGATIVE = testnyka_NEGATIVE[testnyka_NEGATIVE["content"].str.contains("Good|nice|Nice|good|good app|ok")==False]
testnyka_NEGATIVE
# Out:
#                                                  content sentiment_labels
# 27     Very bad service...my order was not delivered ...         NEGATIVE
# 30                         Worst apss ..i have ever seen         NEGATIVE
# 112    i bought a maybelline new york fit me matte+po...         NEGATIVE
# 116    I have been associated with Nykaa from last 1 ...         NEGATIVE
# 125    When i open the app ...it just takes toooo lon...         NEGATIVE
# ...                                                  ...              ...
# 38825                               delivery is too late         NEGATIVE
# 38840                                   I hated this aap         NEGATIVE
# 38853                                 Loading takes time         NEGATIVE
# 38857  Hate it.. I had applied a coupon which was suc...         NEGATIVE
# 38884  I have bought nova products dat are amazing in...         NEGATIVE
#
# [2605 rows x 2 columns]

# %%
testnyka_NEGATIVE.to_csv("testnyka_NEGATIVE.csv")
