# %%
import numpy as np
import pandas as pd

# %%
Mysejnegetive = pd.read_csv('/content/cleanedmysejthrarating1.csv')
Mysejnegetive.head()
# Out:
#                                               Review  Rating
# 0  click everything submit response latest update...       1
# 1  app suddenly change status close contact sympt...       1
# 2  completed home isolation status still show cat...       1
# 3  answering covid status assessment january time...       1
# 4  booster jab first week dec sent multiple email...       1

# %%
Mysejnegetive.shape
# Out:
# (20343, 2)

# %%
Mysejnegetive1 = Mysejnegetive[Mysejnegetive["Review"].str.contains("nice|ok|avarage")==True]
Mysejnegetive1.shape
# Out:
# (775, 2)

# %%
Mysejnegetive = Mysejnegetive[Mysejnegetive["Review"].str.contains("nice|ok|avarage")==False]
Mysejnegetive.shape
# Out:
# (19560, 2)

# %%
# Mysejnegetive1.to_csv('Mysejnegetive1.csv',index=False)

# %%
# Mysejnegetive.to_csv('Mysejnegetive11.csv',index=False)

# %%
#Step2
Mysejnegetive21 = Mysejnegetive[Mysejnegetive["Review"].str.contains("cant|can not|poor|bad|bug|bugs|slow")==True]
Mysejnegetive21.shape
# Out:
# (2880, 2)

# %%
Mysejnegetive21.to_csv('Mysejnegetive21.csv',index=False)

# %%
Mysejnegetive = Mysejnegetive[Mysejnegetive["Review"].str.contains("cant|can not|poor|bad|bug|bugs|slow")==False]
Mysejnegetive.shape
# Out:
# (16680, 2)

# %%
#Step3
Mysejnegetive31 = Mysejnegetive[Mysejnegetive["Review"].str.contains("please|waste|stupid|useless|worst|scame|fake|disappointed")==True]
Mysejnegetive31.shape
# Out:
# (2075, 2)

# %%
Mysejnegetive31.to_csv('Mysejnegetive31.csv',index=False)

# %%
Mysejnegetive = Mysejnegetive[Mysejnegetive["Review"].str.contains("please|waste|stupid|useless|worst|scame|fake|disappointed")==False]
Mysejnegetive.shape
# Out:
# (14605, 2)

# %%
#Step4
Mysejnegetive41 = Mysejnegetive[Mysejnegetive["Review"].str.contains("lagging|problem|terrible")==True]
Mysejnegetive41.shape
# Out:
# (508, 2)

# %%
Mysejnegetive41.to_csv('Mysejnegetive41.csv',index=False)

# %%
Mysejnegetive = Mysejnegetive[Mysejnegetive["Review"].str.contains("lagging|problem|terrible")==False]
Mysejnegetive.shape
# Out:
# (14097, 2)

# %%
Mysejnegetive.to_csv('Mysejnegetive4.csv',index=False)
