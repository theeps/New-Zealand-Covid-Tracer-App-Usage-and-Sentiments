# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
MysejthraRat14 = pd.read_csv('/content/drive/MyDrive/Final Dataset/MysejthraRat14.csv')
MysejthraRat14.head()
# Out:
#                                               Review  Rating
# 0                  mysejahtera app update sign check       3
# 1                              updated version check       3
# 2  glad see auto checkout finally kudos team addi...       5
# 3                            must apps stay malaysia       5
# 4  hi think apps make reminder notification users...       5

# %%
#step 15
MysejthraRat151 = MysejthraRat14[MysejthraRat14["Review"].str.contains("friendly|user friendly")==True]
MysejthraRat151.shape
# Out:
# (690, 2)

# %%
MysejthraRat15 = MysejthraRat14[MysejthraRat14["Review"].str.contains("friendly|user friendly")==False]
MysejthraRat15.shape
# Out:
# (17243, 2)

# %%
MysejthraRat151.to_csv('MysejthraRat151.csv',index=False)

# %%
#step 16
MysejthraRat16 = MysejthraRat15[MysejthraRat15["Review"].str.contains("glitch")==False]
MysejthraRat16.shape
# Out:
# (17241, 2)
