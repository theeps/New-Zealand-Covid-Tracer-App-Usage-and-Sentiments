# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
df=pd.read_csv(r'/content/Mysejahtera_Playstore.csv')
df.head()
# Out:
#          Date  Rating                                             Review
# 0  2022-02-21       1                             Rumit untuk dijelaskan
# 1  2022-02-21       5                                               good
# 2  2022-02-21       1  Is there a limited "operating hour" to receive...
# 3  2022-02-21       1  Bad app, I've been trying to update my vaccina...
# 4  2022-02-21       1  Please mudahkanla kerja rakyat ini lagi susahk...

# %%
df.shape
# Out:
# (117757, 3)

# %%
df_2=pd.read_csv(r'/content/MySejahtera_AppStore.csv')#,index_col='Date',parse_dates=True
df_2.head()
# Out:
#          Date  Rating                                             Review
# 0  2022-02-18       1  After click everything and submit there is no ...
# 1  2022-02-17       5  Great app! But I need help…. My “Covid-19 Stat...
# 2  2022-02-17       3  Hi got problem with my health status. Still no...
# 3  2022-02-16       1  Please upgrade your apps. I’m positive case so...
# 4  2022-02-16       1  Dear developer, I really need your help to che...

# %%
df_2.shape
# Out:
# (3060, 3)

# %%
mysejahtera_1 = pd.concat([df,df_2], axis=0, join="inner")
mysejahtera_1
# Out:
#             Date  Rating                                             Review
# 0     2022-02-21       1                             Rumit untuk dijelaskan
# 1     2022-02-21       5                                               good
# 2     2022-02-21       1  Is there a limited "operating hour" to receive...
# 3     2022-02-21       1  Bad app, I've been trying to update my vaccina...
# 4     2022-02-21       1  Please mudahkanla kerja rakyat ini lagi susahk...
# ...          ...     ...                                                ...
# 3055  2020-04-19       3  1. Can you add the statistics of how many peop...
# 3056  2020-04-17       5  Can you add a table form so we can jot down ou...
# 3057  2020-04-16       4  Doesn’t overload users with unnecessary inform...
# 3058  2020-04-16       4  Unable to track whether a location is infected...
# 3059  2020-04-06       5  Hi, \nThe is good as notification and updates ...
#
# [120817 rows x 3 columns]

# %%
# Dframes=[df,df_2]
# df_Merge=pd.concat(Dframes)
# df_Merge

# %%
mysejahtera_1.shape
# Out:
# (120817, 3)

# %%
mysejahtera_1["Rating"].value_counts().plot(kind="bar",title="test",figsize=(10,6))
plt.title("Total Ratings Count")
plt.xlabel("Ratings")
plt.ylabel("Total Counts")
# Out:
# Text(0, 0.5, 'Total Counts')

# %%
mysejahtera_1.isnull().sum()
# Out:
# Date      0
# Rating    0
# Review    9
# dtype: int64

# %%
list=['Rating']

for i in list:
    print('{} has unique values as {}'.format(i,mysejahtera_1[i].unique()))
# Out:
# Rating has unique values as [1 5 2 4 3]

# %%
mysejahtera_1["Rating"].value_counts()
# Out:
# 5    74761
# 1    22100
# 4    13211
# 3     6792
# 2     3953
# Name: Rating, dtype: int64

# %%
sns.countplot(data = mysejahtera_1, x = 'Rating')
plt.title("Total Ratings Count")
plt.xlabel("Ratings")
plt.ylabel("Total Counts")
# Out:
# Text(0, 0.5, 'Total Counts')

# %%
mysejahtera_1["Rating"].describe()
# Out:
# count    120817.000000
# mean          3.948376
# std           1.565099
# min           1.000000
# 25%           3.000000
# 50%           5.000000
# 75%           5.000000
# max           5.000000
# Name: Rating, dtype: float64

# %%
sns.distplot(mysejahtera_1['Rating'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import datetime as dt

mysejahtera_1.sort_values(by='Date',ascending=False)
mysejahtera_1.head()
# Out:
#          Date  Rating                                             Review
# 0  2022-02-21       1                             Rumit untuk dijelaskan
# 1  2022-02-21       5                                               good
# 2  2022-02-21       1  Is there a limited "operating hour" to receive...
# 3  2022-02-21       1  Bad app, I've been trying to update my vaccina...
# 4  2022-02-21       1  Please mudahkanla kerja rakyat ini lagi susahk...

# %%
mysejahtera_1.shape
# Out:
# (120817, 3)

# %%
mysejahtera_1.to_csv("mysejahtera_Merged.csv",index=False)
