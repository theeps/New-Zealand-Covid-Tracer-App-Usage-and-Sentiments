# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
MysejthraRat8 = pd.read_csv('/content/drive/MyDrive/Final Dataset/MysejthraRat8.csv')
MysejthraRat8.head()
# Out:
#                                               Review  Rating
# 0                  mysejahtera app update sign check       3
# 1                              updated version check       3
# 2  glad see auto checkout finally kudos team addi...       5
# 3  app automatically checked previous location ch...       5
# 4                            must apps stay malaysia       5

# %%
MysejthraRat8.shape
# Out:
# (33263, 2)

# %%
#step 9
MysejthraRat91 = MysejthraRat8[MysejthraRat8["Review"].str.contains("enhance|helpful|accurate|accuratly|easy|help|helps|useful")==True]
MysejthraRat91.shape
# Out:
# (7962, 2)

# %%
MysejthraRat9 = MysejthraRat8[MysejthraRat8["Review"].str.contains("enhance|helpful|accurate|accuratly|easy|help|helps|useful")==False]
MysejthraRat9.shape
# Out:
# (25206, 2)

# %%
MysejthraRat91.to_csv('MysejthraRat91.csv',index=False)

# %%
#step 10
MysejthraRat101 = MysejthraRat9[MysejthraRat9["Review"].str.contains("wonderful|smooth|excellent|full|faster|fast|easier")==True]
MysejthraRat101.shape
# Out:
# (2655, 2)

# %%
MysejthraRat10 = MysejthraRat9[MysejthraRat9["Review"].str.contains("wonderful|smooth|excellent|full|faster|fast|easier")==False]
MysejthraRat10.shape
# Out:
# (22551, 2)

# %%
MysejthraRat101.to_csv('MysejthraRat101.csv',index=False)

# %%
#step 11
MysejthraRat111 = MysejthraRat10[MysejthraRat10["Review"].str.contains("informative|fastest|smoothlly|well|really|new|fast|great")==True]
MysejthraRat111.shape
# Out:
# (1902, 2)

# %%
MysejthraRat11 = MysejthraRat10[MysejthraRat10["Review"].str.contains("informative|fastest|smoothlly|well|really|new|fast|great")==False]
MysejthraRat11.shape
# Out:
# (20649, 2)

# %%
MysejthraRat111.to_csv('MysejthraRat111.csv',index=False)

# %%
#step 12
MysejthraRat121 = MysejthraRat11[MysejthraRat11["Review"].str.contains("awesome|success|proud|time saving|excellent")==True]
MysejthraRat121.shape
# Out:
# (563, 2)

# %%
MysejthraRat12 = MysejthraRat11[MysejthraRat11["Review"].str.contains("awesome|success|proud|time saving|excellent")==False]
MysejthraRat12.shape
# Out:
# (20086, 2)

# %%
MysejthraRat121.to_csv('MysejthraRat121.csv',index=False)

# %%
#step 13
MysejthraRat131 = MysejthraRat12[MysejthraRat12["Review"].str.contains("best|works fine|wonderful|greatest|love|superb apps|superb")==True]
MysejthraRat131.shape
# Out:
# (1805, 2)

# %%
MysejthraRat13 = MysejthraRat12[MysejthraRat12["Review"].str.contains("best|works fine|wonderful|greatest|love|superb apps|superb")==False]
MysejthraRat13.shape
# Out:
# (18281, 2)

# %%
MysejthraRat131.to_csv('MysejthraRat131.csv',index=False)

# %%
#step 14
MysejthraRat141 = MysejthraRat13[MysejthraRat13["Review"].str.contains("need|cant|issue|failed|want|virus|failure")==True]
MysejthraRat141.shape
# Out:
# (348, 2)

# %%
MysejthraRat14 = MysejthraRat13[MysejthraRat13["Review"].str.contains("need|cant|issue|failed|want|virus|failiure")==False]
MysejthraRat14.shape
# Out:
# (17933, 2)

# %%
MysejthraRat141.to_csv('MysejthraRat141.csv',index=False)

# %%
MysejthraRat14.head(20)
# Out:
#                                                Review  Rating
# 0                   mysejahtera app update sign check       3
# 1                               updated version check       3
# 2   glad see auto checkout finally kudos team addi...       5
# 4                             must apps stay malaysia       5
# 5   hi think apps make reminder notification users...       5
# 6   auto checkout system location coverage apps de...       5
# 8      suggested check check different colors history       5
# 13   suggest auto check user checking place afterward       5
# 17  update said partially vaccinated already get dose       5
# 18  additional taps tap display risk vaccination s...       5
# 23  convenient apps friendly use always keep publi...       5
# 25  strongly urge app developer update vaccine cer...       5
# 29                        seriously use everyday apps       5
# 30                    shabby consider perfect country       5
# ...

# %%
MysejthraRat14.head(20)
# Out:
#                                                Review  Rating
# 0                   mysejahtera app update sign check       3
# 1                               updated version check       3
# 2   glad see auto checkout finally kudos team addi...       5
# 4                             must apps stay malaysia       5
# 5   hi think apps make reminder notification users...       5
# 6   auto checkout system location coverage apps de...       5
# 8      suggested check check different colors history       5
# 13   suggest auto check user checking place afterward       5
# 17  update said partially vaccinated already get dose       5
# 18  additional taps tap display risk vaccination s...       5
# 23  convenient apps friendly use always keep publi...       5
# 25  strongly urge app developer update vaccine cer...       5
# 29                        seriously use everyday apps       5
# 30                    shabby consider perfect country       5
# ...

# %%
MysejthraRat14.to_csv('MysejthraRat14.csv',index=False)

# %%
MysejthraRat811 = pd.read_csv('/content/MysejthraRat81.csv')
MysejthraRat811.shape
# Out:
# (1280, 2)

# %%
MysejthraRat812 = MysejthraRat811[MysejthraRat811["Review"].str.contains("thank|like")==False]
MysejthraRat812.shape
